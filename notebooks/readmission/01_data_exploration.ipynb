# %%
# Getting Started...

# %%
# Initial Imports
# For proper python "folder gymnastics"

import sys
from pathlib import Path

# Get the directory of the current notebook, go up two levels, and convert to a string
root_path = str(Path.cwd().parent.parent)

# Add that root directory to sys.path so Python can "see" config.py
if root_path not in sys.path:
    sys.path.append(root_path)

from config import DATABASE_URL
# Out:
# Loaded config from: /Users/chuck/swdev/med/med-z1/.env
#       Project root: /Users/chuck/swdev/med/med-z1
#     CDWWORK server: 127.0.0.1,1433 / DB: CDWWork
#    CDWWORK2 server: 127.0.0.1,1433 / DB: CDWWork2
#     MinIO endpoint: localhost:9000, bucket: med-z1
#          USE_MINIO: True
#         PostgreSQL: localhost:5432 / DB: medz1
#       CCOW enabled: True, URL: http://localhost:8001
#      Vista enabled: True, URL: http://localhost:8003
#    Session timeout: 25 minutes

# %%
# Additional Imports
# For Apple Silicon machines: brew install libomp
import pandas as pd
import sklearn
import xgboost as xgb
import shap
import imblearn

from sqlalchemy import create_engine

# %%
# Show library version numbers

print(f"Pandas:       {pd.__version__}")
print(f"Scikit-Learn: {sklearn.__version__}")
print(f"XGBoost:      {xgb.__version__}")
print(f"SHAP:         {shap.__version__}")
print(f"ImbLearn:     {imblearn.__version__}")

print(f"DATABASE_URL: {DATABASE_URL}")
# Out:
# Pandas:       2.3.3
# Scikit-Learn: 1.8.0
# XGBoost:      3.1.3
# SHAP:         0.50.0
# ImbLearn:     0.14.1
# DATABASE_URL: postgresql://postgres:AllieD-1993-2025-z1@localhost:5432/medz1

# %%
# Connecting to med-z1 PostgreSQL
# Database Schema to Query:
#  - clinical.patient_encounters - Hospital admissions (your target events)
#  - clinical.patient_demographics - Age, sex, DOB
#  - clinical.patient_medications_outpatient - Active meds (polypharmacy feature)
#  - clinical.patient_vitals - BP, weight, temp (clinical instability features)
#  - clinical.patient_labs - Creatinine, Hgb (abnormal lab features)

# Create database connection
engine = create_engine(DATABASE_URL)

# %%
# Let's try a database query (patient_demographics)

patient_demographics_query = """
SELECT
    patient_key,
    patient_sid,
    icn,
    ssn,
    name_last,
    name_first,
    age
FROM clinical.patient_demographics
ORDER BY name_last
"""

# Load into pandas DataFrame
patient_demographics_df = pd.read_sql(patient_demographics_query, engine)

patient_demographics_df
# Out:
#       patient_key  patient_sid            icn        ssn   name_last  \
# 0       ICN100007         1007      ICN100007  111221007      Amajor
# 1       ICN100010         1010      ICN100010  111221010      Aminor
# 2     1022V789012         1022    1022V789012  444401022    Anderson
# 3       ICN100017         1027      ICN100017  999991027    Anderson
# 4       ICN100008         1008      ICN100008  111221008      Bmajor
# 5     1018V345678         1018    1018V345678  999991018        Chen
# 6       ICN100009         1009      ICN100009  111221009      Cmajor
# 7       ICN100001         1001      ICN100001  123456789      Dooree
# 8       ICN100005         1005      ICN100005  111111105      Dooree
# 9     1021V678901         1021    1021V678901  333301021      Garcia
# 10      ICN100011         1011      ICN100011  222221011      Harris
# 11    1016V123456         1016    1016V123456  777771016     Johnson
# 12      ICN100014         1014      ICN100014  555551014         Kim
# 13    1023V890123         1023    1023V890123  555501023         Lee
# 14    1025V012345         1025    1025V012345  777701025    Martinez
# 15      ICN100012         1012      ICN100012  333331012    Martinez
# 16      ICN100006         1006      ICN100006  111111106      Miifaa
# 17      ICN100002         1002      ICN100002  987654321      Miifaa
# 18    1019V456789         1019    1019V456789  111101019   Rodriguez
# 19      ICN100003         1003      ICN100003  111111111       Soola
# 20      ICN100013         1013      ICN100013  444441013    Thompson
# 21    1020V567890         1020    1020V567890  222201020    Thompson
# 22      ICN100004         1004      ICN100004  111112222      Tiidoo
# 23    1024V901234         1024    1024V901234  666601024       White
# 24    1017V234567         1017    1017V234567  888881017    Williams
# 25      ICN100015         1015      ICN100015  666661015      Wilson
# 26      ICN100016         1026      ICN100016  888881026      Wilson
# 27  ICN1044960811      1606025  ICN1044960811  000001235          ZZ
# 28  ICN1012921808      1606021  ICN1012921808  000005288      ZZDUCK
# 29  ICN1018126026      1606027  ICN1018126026  000002158      ZZTEST
# 30  ICN1011936271      1606030  ICN1011936271  000000145      ZZTEST
# 31  ICN1011533925      1606024  ICN1011533925  000009934      ZZTEST
# 32  ICN1051720886      1606023  ICN1051720886  000000970      ZZTEST
# 33  ICN1060349008      1606022  ICN1060349008  000000188      ZZTEST
# 34  ICN1019425664      1606020  ICN1019425664  000005003      ZZTEST
# 35  ICN1021290240      1606028  ICN1021290240  000005550      ZZTEST
# 36  ICN1018448811      1606029  ICN1018448811  000005755  ZZTEST PAT
# 37  ICN1011530429      1606026  ICN1011530429  000008887         ZZZ
#
#    name_first  age
# 0        Adam   86
# 1   Alexander   60
# 2       James   62
# 3      Robert   47
# 4       Barry   65
# 5       David   43
# 6      Claire   66
# 7        Adam   46
# 8      Edward   44
# 9    Patricia   59
# 10     George   72
# 11     Marcus   29
# 12      Joyce   70
# 13    Barbara   68
# 14    Dorothy   80
# 15      Helen   68
# 16   Francine   44
# 17      Barry   51
# 18      Linda   49
# 19      Carol   36
# 20     Irving   77
# 21     Robert   54
# 22      Debby   72
# 23    Charles   75
# 24      Sarah   36
# 25    Kenneth   82
# 26   Margaret   87
# 27    PATIENT   84
# 28       DONN  125
# 29     MOLLIE   76
# 30       BILL   81
# 31    DONNA R   30
# 32      APPLE   55
# 33        ABC   38
# 34     CCINDY   65
# 35        CHI   89
# 36       FIVE   80
# 37       TEST   53

# %%
# Let's try a database query (patient_encounters)

# Query 1
pt_encounters_count = """
    select count(*)
    from clinical.patient_encounters
"""

# Query 2
pt_encounters_query = """
SELECT
    e.patient_key,
    d.name_first as first,
    d.name_last as last,
    d.age,
    d.sex,
    e.sta3n,
    e.admitting_provider_name as admit_provider,
    e.admit_datetime::DATE as admit_date,
    e.discharge_datetime::DATE as discharge_date,
    e.discharge_disposition as disposition
FROM clinical.patient_encounters as e
INNER JOIN clinical.patient_demographics AS d 
    ON e.patient_key = d.patient_key
WHERE e.discharge_datetime IS NOT NULL
ORDER BY e.patient_key DESC, e.discharge_datetime
"""

# Load Query 1 into pandas DataFrame and display
pt_encounters_df = pd.read_sql(pt_encounters_count, engine)

# Load Query 2 into pandas DataFrame and display
pt_encounters_df = pd.read_sql(pt_encounters_query, engine)
print(f"Shape: {pt_encounters_df.shape}")
pt_encounters_df.head(35)
# Out:
# Shape: (72, 10)
#    patient_key      first      last  age sex sta3n        admit_provider  \
# 0    ICN100017     Robert  Anderson   47   M   528            Carl Sagan
# 1    ICN100017     Robert  Anderson   47   M   528            Carl Sagan
# 2    ICN100017     Robert  Anderson   47   M   528        Julius Hibbert
# 3    ICN100016   Margaret    Wilson   87   F   508           Walter Reed
# 4    ICN100014      Joyce       Kim   70   F   516           Marie Curry
# 5    ICN100013     Irving  Thompson   77   M   508           Walter Reed
# 6    ICN100012      Helen  Martinez   68   F   688            Carl Sagan
# 7    ICN100011     George    Harris   72   M   552  Florence Nightengale
# 8    ICN100010  Alexander    Aminor   60   M   516           Marie Curry
# 9    ICN100009     Claire    Cmajor   66   F   508  Florence Nightengale
# 10   ICN100008      Barry    Bmajor   65   M   688  Florence Nightengale
# 11   ICN100007       Adam    Amajor   86   M   552  Florence Nightengale
# 12   ICN100006   Francine    Miifaa   44   F   516           Marie Curry
# 13   ICN100005     Edward    Dooree   44   M   508           Walter Reed
# 14   ICN100004      Debby    Tiidoo   72   F   552         Louis Pasteur
# 15   ICN100004      Debby    Tiidoo   72   F   516         Louis Pasteur
# 16   ICN100004      Debby    Tiidoo   72   F   508         Louis Pasteur
# 17   ICN100004      Debby    Tiidoo   72   F   508            Carl Sagan
# 18   ICN100004      Debby    Tiidoo   72   F   688            Carl Sagan
# 19   ICN100004      Debby    Tiidoo   72   F   552            Carl Sagan
# 20   ICN100004      Debby    Tiidoo   72   F   516            Carl Sagan
# 21   ICN100004      Debby    Tiidoo   72   F   508            Carl Sagan
# 22   ICN100004      Debby    Tiidoo   72   F   688            Carl Sagan
# 23   ICN100004      Debby    Tiidoo   72   F   552            Carl Sagan
# 24   ICN100004      Debby    Tiidoo   72   F   516            Carl Sagan
# 25   ICN100004      Debby    Tiidoo   72   F   508            Carl Sagan
# 26   ICN100004      Debby    Tiidoo   72   F   688            Carl Sagan
# 27   ICN100004      Debby    Tiidoo   72   F   552            Carl Sagan
# 28   ICN100001       Adam    Dooree   46   M   688        Julius Hibbert
# 29   ICN100001       Adam    Dooree   46   M   552        Julius Hibbert
# 30   ICN100001       Adam    Dooree   46   M   516        Julius Hibbert
# 31   ICN100001       Adam    Dooree   46   M   508        Julius Hibbert
# 32   ICN100001       Adam    Dooree   46   M   552  Florence Nightengale
# 33   ICN100001       Adam    Dooree   46   M   552        Julius Hibbert
# 34   ICN100001       Adam    Dooree   46   M   516        Julius Hibbert
#
#     admit_date discharge_date                        disposition
# 0   2019-06-20     2019-06-28  TRANSFERRED TO MENTAL HEALTH UNIT
# 1   2023-03-10     2023-03-17     HOME WITH OUTPATIENT FOLLOW-UP
# 2   2024-11-15     2024-11-15                            EXPIRED
# 3   2024-11-25     2024-12-01                            EXPIRED
# 4   2025-11-17     2025-11-22                                SNF
# 5   2025-11-20     2025-11-24                               Home
# 6   2025-11-25     2025-11-25                               Home
# 7   2025-11-27     2025-11-27                               Home
# 8   2025-11-30     2025-11-30                               Home
# 9   2025-11-28     2025-12-03                              Rehab
# 10  2025-11-30     2025-12-05                                SNF
# 11  2025-12-01     2025-12-08                       Home with O2
# 12  2025-12-05     2025-12-10                               Home
# 13  2025-12-09     2025-12-12                               Home
# 14  2024-05-29     2024-06-03                                SNF
# 15  2024-08-07     2024-08-12                       Home with O2
# 16  2024-10-16     2024-10-21                               Home
# 17  2025-03-26     2025-03-30                                SNF
# 18  2025-04-25     2025-04-29                       Home with O2
# 19  2025-05-25     2025-05-29                               Home
# 20  2025-06-24     2025-06-28                               Home
# 21  2025-07-24     2025-07-28                              Rehab
# 22  2025-08-23     2025-08-27                                SNF
# 23  2025-09-22     2025-09-26                       Home with O2
# 24  2025-10-22     2025-10-26                               Home
# 25  2025-11-24     2025-11-27                                SNF
# 26  2025-11-29     2025-12-02                       Home with O2
# 27  2025-12-04     2025-12-07                               Home
# 28  2024-05-09     2024-05-14                              Rehab
# 29  2024-07-08     2024-07-13                                SNF
# 30  2024-09-06     2024-09-11                       Home with O2
# 31  2024-11-05     2024-11-10                               Home
# 32  2024-12-20     2024-12-24                               Home
# 33  2025-01-25     2025-01-29                               Home
# 34  2025-02-14     2025-02-18                              Rehab

# %%
# Display again
print(f"Shape: {pt_encounters_df.shape}")
pt_encounters_df.tail(35)
# Out:
# Shape: (72, 10)
#     patient_key     first       last  age sex sta3n        admit_provider  \
# 37    ICN100001      Adam     Dooree   46   M   688        Julius Hibbert
# 38    ICN100001      Adam     Dooree   46   M   552        Julius Hibbert
# 39    ICN100001      Adam     Dooree   46   M   516        Julius Hibbert
# 40    ICN100001      Adam     Dooree   46   M   516           Marie Curry
# 41    ICN100001      Adam     Dooree   46   M   508        Julius Hibbert
# 42    ICN100001      Adam     Dooree   46   M   688        Julius Hibbert
# 43    ICN100001      Adam     Dooree   46   M   552        Julius Hibbert
# 44    ICN100001      Adam     Dooree   46   M   516        Julius Hibbert
# 45    ICN100001      Adam     Dooree   46   M   508        Julius Hibbert
# 46    ICN100001      Adam     Dooree   46   M   508  Florence Nightengale
# 47    ICN100001      Adam     Dooree   46   M   688        Julius Hibbert
# 48    ICN100001      Adam     Dooree   46   M   552        Julius Hibbert
# 49    ICN100001      Adam     Dooree   46   M   516        Julius Hibbert
# 50    ICN100001      Adam     Dooree   46   M   508        Julius Hibbert
# 51    ICN100001      Adam     Dooree   46   M   508           Walter Reed
# 52    ICN100001      Adam     Dooree   46   M   508        Julius Hibbert
# 53    ICN100001      Adam     Dooree   46   M   688        Julius Hibbert
# 54    ICN100001      Adam     Dooree   46   M   552        Julius Hibbert
# 55    ICN100001      Adam     Dooree   46   M   516        Julius Hibbert
# 56    ICN100001      Adam     Dooree   46   M   508        Julius Hibbert
# 57  1025V012345   Dorothy   Martinez   80   F   508                  None
# 58  1025V012345   Dorothy   Martinez   80   F   516         Louis Pasteur
# 59  1024V901234   Charles      White   75   M   688                  None
# 60  1024V901234   Charles      White   75   M   508            Carl Sagan
# 61  1023V890123   Barbara        Lee   68   F   552                  None
# 62  1023V890123   Barbara        Lee   68   F   552  Florence Nightengale
# 63  1022V789012     James   Anderson   62   M   516                  None
# 64  1022V789012     James   Anderson   62   M   516           Marie Curry
# 65  1021V678901  Patricia     Garcia   59   F   508                  None
# 66  1021V678901  Patricia     Garcia   59   F   688            Carl Sagan
# 67  1020V567890    Robert   Thompson   54   M   552  Florence Nightengale
# 68  1019V456789     Linda  Rodriguez   49   F   508  Florence Nightengale
# 69  1018V345678     David       Chen   43   M   688            Carl Sagan
# 70  1017V234567     Sarah   Williams   36   F   552  Florence Nightengale
# 71  1016V123456    Marcus    Johnson   29   M   516           Marie Curry
#
#     admit_date discharge_date   disposition
# 37  2025-03-26     2025-03-30  Home with O2
# 38  2025-04-15     2025-04-19          Home
# 39  2025-05-05     2025-05-09          Home
# 40  2025-05-19     2025-05-25          Home
# 41  2025-05-25     2025-05-29         Rehab
# 42  2025-06-14     2025-06-18           SNF
# 43  2025-07-04     2025-07-08  Home with O2
# 44  2025-07-24     2025-07-28          Home
# 45  2025-08-13     2025-08-17          Home
# 46  2025-08-17     2025-08-20          Home
# 47  2025-09-02     2025-09-06         Rehab
# 48  2025-09-22     2025-09-26           SNF
# 49  2025-10-12     2025-10-16  Home with O2
# 50  2025-11-01     2025-11-05          Home
# 51  2025-11-08     2025-11-10          Home
# 52  2025-11-20     2025-11-23          Home
# 53  2025-11-24     2025-11-27         Rehab
# 54  2025-11-28     2025-12-01           SNF
# 55  2025-12-02     2025-12-05  Home with O2
# 56  2025-12-06     2025-12-09          Home
# 57  2024-04-24     2024-04-29  Home with O2
# 58  2024-12-25     2024-12-29         Rehab
# 59  2024-06-13     2024-06-20           SNF
# 60  2024-12-30     2025-01-03          Home
# 61  2024-08-02     2024-08-08          Home
# 62  2025-01-09     2025-01-11          Home
# 63  2024-09-21     2024-09-25         Rehab
# 64  2025-01-29     2025-02-02          Home
# 65  2024-11-10     2024-11-15          Home
# 66  2025-03-20     2025-03-24          Home
# 67  2025-04-19     2025-04-22          Home
# 68  2025-06-18     2025-06-21          Home
# 69  2025-07-18     2025-07-23          Home
# 70  2025-09-16     2025-09-19          Home
# 71  2025-10-16     2025-10-20  Home with O2

# %%
# Sort DataFrame
pt_encounters_df = pt_encounters_df.sort_values(['patient_key', 'discharge_date'])
pt_encounters_df
# Out:
#     patient_key     first       last  age sex sta3n        admit_provider  \
# 71  1016V123456    Marcus    Johnson   29   M   516           Marie Curry
# 70  1017V234567     Sarah   Williams   36   F   552  Florence Nightengale
# 69  1018V345678     David       Chen   43   M   688            Carl Sagan
# 68  1019V456789     Linda  Rodriguez   49   F   508  Florence Nightengale
# 67  1020V567890    Robert   Thompson   54   M   552  Florence Nightengale
# ..          ...       ...        ...  ...  ..   ...                   ...
# 4     ICN100014     Joyce        Kim   70   F   516           Marie Curry
# 3     ICN100016  Margaret     Wilson   87   F   508           Walter Reed
# 0     ICN100017    Robert   Anderson   47   M   528            Carl Sagan
# 1     ICN100017    Robert   Anderson   47   M   528            Carl Sagan
# 2     ICN100017    Robert   Anderson   47   M   528        Julius Hibbert
#
#     admit_date discharge_date                        disposition
# 71  2025-10-16     2025-10-20                       Home with O2
# 70  2025-09-16     2025-09-19                               Home
# 69  2025-07-18     2025-07-23                               Home
# 68  2025-06-18     2025-06-21                               Home
# 67  2025-04-19     2025-04-22                               Home
# ..         ...            ...                                ...
# 4   2025-11-17     2025-11-22                                SNF
# 3   2024-11-25     2024-12-01                            EXPIRED
# 0   2019-06-20     2019-06-28  TRANSFERRED TO MENTAL HEALTH UNIT
# 1   2023-03-10     2023-03-17     HOME WITH OUTPATIENT FOLLOW-UP
# 2   2024-11-15     2024-11-15                            EXPIRED
#
# [72 rows x 10 columns]
